# %% [markdown]
# ### History of AWS So Far
#
# This lesson gives context where aws is and where it is going
#
# CEO of aws services Andy Jassy states 'invenstion requres two things:
# 1. The ability to try a log of experiments
# 2. not having to live with the collateral damage of failed experiments
#
# Startups can try a product, and easily terminate it if it fails. Do not need to be locked into a service contract.
#
# - 2003 - AWS started marketing as a service
# - 2004 - SQS released
# - 2006 - AWS launched
# - 2007 - 180,000 developers
# - 2010 - all of amazon moved to aws
# - 2012 - first re:invent conference
# - 2013 - released certifications
# - 2014 - commited to achieve 100% renewable engery
# - 2015 - aws revenue is 6 billion USD yearly
# - 2016 - run rate of 13 billion
# - 2017 - aws reinvent release AI services and reaches 27 bil
# - 2018 - launch machine learning spec
# - 2019 - release alex specialty

# %% [markdown]
# ### AWS 10,000 foot overiew
#
# services continue to grow and not all are relevant for everyone (esp this cert exam)
#
# Going over the high level services
#
# The us east virginia is the oldest region where services come out first
#
# ### Topics
# - aws global infractructure
# - compute
# - storage
# - databases
# - migration and transfer
# - network and content delivery
# - developer tools (Not needed for solution architecture asso)
# - management and governance
# - machine learning
# - analytics
# - security, identity and compliance
# - desktop and app streaming
#
# Core topics:
# - aws global infractructure
# - compute
# - storage
# - databases
# - network and content delivery
# - security, identity and compliance
#
# #### Global infrastructure
#
# 19 regions
# 57 availability zones
#
# An availability zone is a data center
# - can have serveral data centers a couple of miles from each other
#
# A data center has:
# - a lot of computers, load balancers, firewalls, switches, storage
#
# A region is a geographical area that consist of 2 or more availability zones
#
# Regions can be GovCloud for goverment only
#
# A region has a location, launch date and EC2 availability zones amount
#
# https://aws.amazon.com/about-aws/global-infrastructure/regions_az/
#
#
# Edge location are endpoints for aws which are used for caching content. Typically this consists of cloudfront, amazon's content delivery network (CDN)
#
# There are many more edge locations than regions. Currently over 150 edge locations

# %% [markdown]
# # Quiz:
#
# ### Which of the below are compute service from AWS?
#
# EC2 and Lambda
#
# Both Lambda and EC2 offer computing in the cloud.
#
# S3 is a storage offering while VPC is a network service.
#
# ### Which of the following is correct?
#
# The number of Edge Locations > # of Availability Zones > # of Regions
#
# ### An AWS VPC is a component of which group of AWS services?
#
# Networking Services
#
# A Virtual Private Cloud (VPC) is a virtual network dedicated to a single AWS account. It is logically isolated from other virtual networks in the AWS cloud, providing compute resources with security and robust networking functionality
#
# ### In which of the following is CloudFront content cached?
#
# Edge Location
#
# ### Which of the following are a part of AWS’ Network and Content Delivery services? (Choose 2)
#
# Cloudfront, VPC
#
# VPC allows you to provision a logically isolated section of the AWS where you can launch AWS resources in a virtual network. Cloudfront is a fast, highly secure and programmable content delivery network (CDN).
#
# EC2 provides compute resources while RDS is Amazon's Relational Database System.
#
# ### Which statement best describes Availability Zones?
#
# Distinct locations from within an AWS region that are engineered to be isolated from failures.
#
# An Availability Zone (AZ) is a distinct location within an AWS Region. Each Region comprises at least two AZs. Further information:
#
# ### Which of the below are storage services in AWS? (Choose 2)
#
# S3 and EFS
#
# S3 and EFS both provide the ability to store files in the cloud.
#
# ### What is an AWS region?
#
# A region is a geographical area divided into Availability Zones. Each region contains at least two Availability Zones.
#
# ### What does an AWS Region consist of?
#
# A distinct location within a geographic area designed to provide high availability to a specific geography.
#
# ### Which of the below are database services from AWS? (Choose 2)
#
# DynamoDB
# RDS
#
# RDS is a service for relational databases provided by AWS. DynamoDB is AWS' fast, flexible, no-sql database service.
#
# ### What is an Amazon VPC?
#
# VPC stands for Virtual Private Cloud.
#
# ### Which of the below are factors that have helped make public cloud so powerful? (Choose 2)
#
# The ability to try out new ideas and experiment without an upfront commitment
#
# Not having to deal with the collateral damage of failed experiments
#
# Public cloud allows organisations to try out new ideas, new approaches and experiment with little upfront commitment. If it doesn't work out, organisations have the ability to terminate the resources and stop paying for them.
